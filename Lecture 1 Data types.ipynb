# %% [markdown]
# # Lecture 1. Data types

# %% [markdown]
# ## Sample code

# %%
x = ['α', 'foo', False, 3.0]

# %%
print(x)
# Out:
# ['α', 'foo', False, 3.0]

# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(-5, 5, 100)
# NOTE: first argument to st.norm is mean, second is standard deviation sigma (not sigma^2)
pdf_x = st.norm(0.0, 1.0).pdf(x)
fig, ax = plt.subplots()
ax.set_title(r"Normal Distribution ($\mu = 0, \sigma = 1$)")
ax.plot(x, pdf_x)

# %%
import pandas as pd

# %%
url = 'https://fred.stlouisfed.org/graph/fredgraph.csv?bgcolor=%23e1e9f0&chart_type=line&drp=0&fo=open%20sans&graph_bgcolor=%23ffffff&height=450&mode=fred&recession_bars=on&txtcolor=%23444444&ts=12&tts=12&width=1168&nt=0&thu=0&trc=0&show_legend=yes&show_axis_titles=yes&show_tooltip=yes&id=GDPC1&scale=left&cosd=1947-01-01&coed=2021-10-01&line_color=%234572a7&link_values=false&line_style=solid&mark_type=none&mw=3&lw=2&ost=-99999&oet=99999&mma=0&fml=a&fq=Quarterly&fam=avg&fgst=lin&fgsnd=2020-02-01&line_index=1&transformation=pch&vintage_date=2022-01-27&revision_date=2022-01-27&nd=1947-01-01'
g_data = pd.read_csv(url, index_col=0, parse_dates=True)
g_data.columns = ['Growth']
g_data.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# ## Data types

# %% [markdown]
# ### Numbers and basic math
# Two types of numbers: integers and floats.

# %%
x = 2

# %%
x
# Out:
# 2

# %%
# try y
y # Python does not recognize variables not yet defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/zf/y8sy8tfs10x7msglglywkhw80000gn/T/ipykernel_14573/3563912222.py in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
y = 3.0

# %%
y
# Out:
# 3.0

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %% [markdown]
# type() is a function

# %%
print(x)
# Out:
# 2

# %%
print(y)
# Out:
# 3.0

# %%
print(x,y)
# Out:
# 2 3.0

# %%
z = 3.5

# %%
print(x,y,z)
# Out:
# 2 3.0 3.5

# %%
z = x+y

# %%
z
# Out:
# 5.0

# %%
z = z + 1

# %%
print(z)
# Out:
# 6.0

# %%
x*2
# Out:
# 4

# %%
x/y
# Out:
# 0.6666666666666666

# %%
x**2
# Out:
# 4

# %%
print(x**y)
# Out:
# 8.0

# %% [markdown]
# #### Exercise 1
# Define x = 5, and y = 3.0
# - compute $x^3$
# - compute $z1 = x+y \times x$, and $z2 = (x+y) \times x$
# - print out 'x**2.5 is ' and its result

# %%
x = 5
y = 3.0

# %%
x**3
# Out:
# 125

# %%
print(x**3)
# Out:
# 125

# %%
x+y*x
# Out:
# 20.0

# %%
(x+y)*x
# Out:
# 40.0

# %%
print('x**2.5 is',x**2.5)
# Out:
# x**2.5 is 55.90169943749474

# %% [markdown]
# ### Strings

# %%
x = 'hello'

# %%
type(x)
# Out:
# str

# %%
y = 'world'

# %%
x+y
# Out:
# 'helloworld'

# %%
x+' '+y
# Out:
# 'hello world'

# %%
y*3
# Out:
# 'worldworldworld'

# %%
print('hello '+y)
# Out:
# hello world

# %%
x = '7'

# %%
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 7

# %%
float(x)
# Out:
# 7.0

# %%
input('enter something:')
# Out:
# enter something:7
# '7'

# %%
s = input('enter something:')
# Out:
# enter something:7

# %%
s
# Out:
# '7'

# %%
type(s)
# Out:
# str

# %% [markdown]
# ### Exercise 2
# Ask users to input a number, and define a variable that is a float, which has the value of this number

# %%
s = float(input('Please enter a number:'))
# Out:
# Please enter a number:7

# %%
type(s)
# Out:
# float

# %% [markdown]
# #### string methods

# %%
x = 'Hello World'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.count('l')
# Out:
# 3

# %%
x.split()
# Out:
# ['Hello', 'World']

# %% [markdown]
# #### String formatting

# %%
country = 'Japan'
GDP = 140.5
year = 2020

# %% [markdown]
# what I want to print: Japan had $140.5 billions in 2020

# %%
print(f'{country} had ${GDP} billions in {year}')
# Out:
# Japan had $140.5 billions in 2020

# %%
x
# Out:
# 'Hello World'

# %%
s2 = f'I just defined x as {x}'

# %%
print(s2)
# Out:
# I just defined x as Hello World

# %% [markdown]
# #### Exercise 3
# * Define a string 'USA', then define a new string that duplicates the word 4 times
# * Define x = 5, and y = 3.0,
#     * print out 'x**2.5 is ' and its result. This time use string formatting
#     * print out 'x+y*x is ' and its result.

# %%
x = 'USA '

# %%
y = x*4
print(y)
# Out:
# USA USA USA USA

# %%
x = 5
y = 3.0

# %%
z = x**2.5

# %%
print(f'x**2.5 is {z}')
# Out:
# x**2.5 is 55.90169943749474

# %%
print(f'x**2.5 is {x**2.5}')
# Out:
# x**2.5 is 55.90169943749474

# %%
print(f'x+y*x is {x+y*x}')
# Out:
# x+y*x is 20.0
